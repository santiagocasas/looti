# %% [markdown]
# # Create looti emulators for observables dependent on only z

# %% [markdown]
# ## Example 1: $\sigma_{8}$

# %% [markdown]
# ## 1) Create a pandas dataframe from data files

# %% [markdown]
# Load looti module read_files

# %%
from looti import read_files as rf

# %% [markdown]
# The path to the data files and other specifications are passed to looti via a yaml file.
# The yaml file should contain the following information:
# - main_dir: the directory in which all relevant folders and files are stored
# - config_file: this file should include a section called where the varying parameters are specified
#
# - folders_path: path to the directory containing all the data folders, one for each class/camb run
# - params_file: each data folder should contain a file specifying the values of each parameter for this run
# - reference folder: name of the folder containing a run with fiducial values used as reference
#
# - z_file_name: file containing the redshift grid
# - k_file_name: file containing the k grid
# - data_file_name: file containing the data to be emulated
# - data_type: name of observable to be emulated

# %% [markdown]
# Create an instance of "FrameConstructor" - the looti class used for data management.
# FrameConstructor takes the path to this yamle file as input

# %%
FrameConstructor = rf.FrameConstructor(path_config_file='../readfile_configs/input4cast_lhs_sigma8.yaml')

# %% [markdown]
# Create a dataframe containing all training and test data

# %%
dataframe_sigma8_ext = FrameConstructor.create_z_dataframe()
dataframe_sigma8_ext
# Out:
#                                                                                                                                                                                                                                                             1    \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.902555
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.611052
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.914669
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.873999
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.738283
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  1.237095
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.838463
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.858764
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.778386
# z_grid                                                                                                                                                                                                                                                 0.000000
#
#                                                                                                                                                                                                                                                             2    \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.878642
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.595482
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.888990
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.852126
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.719825
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  1.202364
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.818647
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.835547
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.757642
# z_grid                                                                                                                                                                                                                                                 0.050000
#
#                                                                                                                                                                                                                                                             3    \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.855364
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.580311
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.864132
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.830912
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.701907
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  1.168857
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.799245
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.812945
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.737169
# z_grid                                                                                                                                                                                                                                                 0.100000
#
#                                                                                                                                                                                                                                                             4    \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.832760
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.565557
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.840121
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.810367
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.684532
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  1.136584
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.780261
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.790993
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.717065
# z_grid                                                                                                                                                                                                                                                 0.150000
#
#                                                                                                                                                                                                                                                             5    \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.810854
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.551231
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.816968
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.790495
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.667698
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  1.105540
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.761722
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.769717
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.697405
# z_grid                                                                                                                                                                                                                                                 0.200000
#
#                                                                                                                                                                                                                                                             6    \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.789661
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.537341
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.794675
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.771292
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.651403
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  1.075709
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.743657
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.749133
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.678251
# z_grid                                                                                                                                                                                                                                                 0.250000
#
#                                                                                                                                                                                                                                                             7    \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.769186
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.523890
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.773233
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.752752
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.635639
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  1.047064
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.726084
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.729247
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.659650
# z_grid                                                                                                                                                                                                                                                 0.300000
#
#                                                                                                                                                                                                                                                             8    \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.749427
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.510877
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.752628
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.734861
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.620400
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  1.019573
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.709010
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.710060
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.641633
# z_grid                                                                                                                                                                                                                                                 0.350000
#
#                                                                                                                                                                                                                                                             9    \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.730378
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.498301
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.732840
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.717604
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.605674
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  0.993198
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.692439
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.691566
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.624221
# z_grid                                                                                                                                                                                                                                                 0.400000
#
#                                                                                                                                                                                                                                                             10   \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.712026
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.486155
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.713844
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.700966
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.591450
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  0.967900
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.676372
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.673755
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.607426
# z_grid                                                                                                                                                                                                                                                 0.450000
#
#                                                                                                                                                                                                                                                        ...  \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value       ...
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   ...
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  ...
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   ...
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  ...
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  ...
# ...                                                                                                                                                                                                                                                    ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  ...
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  ...
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  ...
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  ...
# z_grid                                                                                                                                                                                                                                                 ...
#
#                                                                                                                                                                                                                                                             92   \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.210411
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.145015
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.209550
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.221278
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.180963
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  0.289880
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.205655
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.195195
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.170544
# z_grid                                                                                                                                                                                                                                                 4.550000
#
#                                                                                                                                                                                                                                                             93   \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.208562
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.143742
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.207710
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.219380
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.179381
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  0.287355
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.203851
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.193470
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.169030
# z_grid                                                                                                                                                                                                                                                 4.600000
#
#                                                                                                                                                                                                                                                             94   \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.206744
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.142492
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.205902
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.217513
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.177827
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  0.284873
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.202078
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.191775
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.167542
# z_grid                                                                                                                                                                                                                                                 4.650000
#
#                                                                                                                                                                                                                                                             95   \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.204958
# ...
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.200661
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.212097
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.173320
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  0.277676
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.196938
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.186862
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.163233
# z_grid                                                                                                                                                                                                                                                 4.800000
#
#                                                                                                                                                                                                                                                             98   \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.199779
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.137698
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.198972
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.210350
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.171868
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  0.275357
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.195282
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.185279
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.161845
# z_grid                                                                                                                                                                                                                                                 4.850000
#
#                                                                                                                                                                                                                                                             99   \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.198110
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.136550
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.197311
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.208632
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.170439
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  0.273075
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.193653
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.183723
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.160480
# z_grid                                                                                                                                                                                                                                                 4.900000
#
#                                                                                                                                                                                                                                                             100  \
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.196469
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.135420
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.195678
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.206941
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.169034
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  0.270831
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.192051
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.182193
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.159139
# z_grid                                                                                                                                                                                                                                                 4.950000
#
#                                                                                                                                                                                                                                                             101
# data_type redshift parameter_1 parameter_1_value   parameter_2 parameter_2_value    parameter_3 parameter_3_value   parameter_4 parameter_4_value    parameter_5 parameter_5_value  parameter_6 parameter_6_value  parameter_7 parameter_7_value
# sigma8    0.0      w0_fld      -0.9247648902821317 wa_fld      0.10815047021943569  Omega_m     0.3285266457680251  Omega_b     0.056974921630094044 h           0.6952037617554859 n_s         1.0894043887147336 A_s         2.387406172143852e-09   0.194854
#                                -0.877742946708464  wa_fld      -0.07053291536050157 Omega_m     0.30796238244514107 Omega_b     0.04106583072100313  h           0.5093260188087775 n_s         1.1781818181818182 A_s         2.1073194145180375e-09  0.134309
#                                -0.9075235109717869 wa_fld      0.18181818181818177  Omega_m     0.3661442006269593  Omega_b     0.05603448275862069  h           0.7435109717868339 n_s         1.1179937304075236 A_s         1.740539136674708e-09   0.194071
#                                -0.7789968652037618 wa_fld      0.1833855799373041   Omega_m     0.3024451410658307  Omega_b     0.04874608150470219  h           0.7088557993730408 n_s         1.1345454545454545 A_s         2.4707653261991545e-09  0.205277
#                                -0.7758620689655172 wa_fld      -0.10501567398119122 Omega_m     0.30043887147335424 Omega_b     0.04929467084639498  h           0.6311442006269593 n_s         1.0352351097178683 A_s         2.3440594120350954e-09  0.167652
# ...                                                                                                                                                                                                                                                         ...
#                                -0.835423197492163  wa_fld      0.22100313479623823  Omega_m     0.369153605015674   Omega_b     0.04349529780564263  h           0.8201724137931035 n_s         1.1014420062695924 A_s         2.3540625105217316e-09  0.268623
#                                -0.9012539184952978 wa_fld      0.010971786833855801 Omega_m     0.266833855799373   Omega_b     0.04905956112852664  h           0.7792163009404389 n_s         1.1255172413793102 A_s         1.9272636417585846e-09  0.190475
#                                -0.95141065830721   wa_fld      -0.02664576802507837 Omega_m     0.33905956112852664 Omega_b     0.056818181818181816 h           0.7340595611285267 n_s         1.1270219435736677 A_s         1.6738518134304664e-09  0.180688
#                                -1.2210031347962382 wa_fld      0.053291536050156685 Omega_m     0.32150470219435734 Omega_b     0.0420846394984326   h           0.7004545454545454 n_s         0.7538557993730407 A_s         1.7071954750525872e-09  0.157820
# z_grid                                                                                                                                                                                                                                                 5.000000
#
# [320 rows x 101 columns]

# %% [markdown]
# Save the dataframe

# %%
# dataframe_sigma8_ext.to_csv("../data/rwth_output/class_Asw0wa_DP/sigma8_z.csv")

# %% [markdown]
# Create a dataframe containing reference at fiducial values for the varying parameters at each redshift.

# %%
dataframe_sigma8_ref = FrameConstructor.create_z_reference_dataframe()
dataframe_sigma8_ref
# Out:
# (101,)
#                          1         2         3         4         5    \
# data_type redshift
# sigma8    0.0       0.815716  0.794296  0.773349  0.752924  0.733057
# z_grid              0.000000  0.050000  0.100000  0.150000  0.200000
#
#                          6         7         8         9         10   ...  \
# data_type redshift                                                    ...
# sigma8    0.0       0.713776  0.695098  0.677032  0.659583  0.642746  ...
# z_grid              0.250000  0.300000  0.350000  0.400000  0.450000  ...
#
#                          92        93        94        95        96   \
# data_type redshift
# sigma8    0.0       0.186281  0.184635  0.183017  0.181427  0.179865
# z_grid              4.550000  4.600000  4.650000  4.700000  4.750000
#
#                          97        98        99        100       101
# data_type redshift
# sigma8    0.0       0.178329  0.176819  0.175334  0.173874  0.172438
# z_grid              4.800000  4.850000  4.900000  4.950000  5.000000
#
# [2 rows x 101 columns]

# %% [markdown]
# Save the reference dataframe

# %%
# dataframe_sigma8_ref.to_csv("../data/rwth_output/class_Asw0wa_DP/sigma8_z_ref.csv")

# %% [markdown]
# ## 2) Normalize the data and divide it into training, validation and test sets

# %% [markdown]
# Load looti module datahandle

# %%
from looti import datahandle as dhl

# %% [markdown]
# Specify path and names of the pandas dataframes we just created

# %%
data_folder = '../data/rwth_output/class_Asw0wa_DP/' 
datafile_ext = 'sigma8_z'
datafile_ref = 'sigma8_z_ref'

# %% [markdown]
# Create a DataHandle object and read the csv files containing the data

# %%
emulation_data = dhl.DataHandle(datafile_ext,                   # file name of csv file containing input data
                                data_folder,                    # path to folder containing both external and reference dataframes
                                datafile_ref,                   # file name of csv file containing reference data
                                num_parameters=7,               # number of parameters to be interpolated
                                data_type='sigma8',               # type of observable to be emulated
                                features_name='z_grid',         # name of the grid in the data frames
                                features_to_Log=True,           # 
                                ratio_mode=False) 
emulation_data.read_csv_pandas()
# Out:
# /home/joschafmeister/looti/looti/datahandle.py:133: RuntimeWarning: divide by zero encountered in log10
#   self.fgrid = np.log10(self.fgrid.astype(float))

# %% [markdown]
# Normalize the data (by dividing through the reference and then normalizing by mean and standard deviation)

# %%
emulation_data.calculate_ratio_by_redshifts(emulation_data.z_vals, normalize=True)

# %% [markdown]
# Specify the desired number of training and test data. Additionally there is the option for multiple splits and

# %%
import random
import numpy as np 

n_train = 100                                                 # Number of training vectors without taking acount the extrema 
n_test = 2                                                     # Number of test vectors without taking acount the extrema
n_splits = 1                                                   # Number of splits
test_indices=[random.sample(range(1, 1000), n_test)]           # List of list -of test indices, one list per split

z_list = list(np.loadtxt('../../input4cast/output/mg_camb_lhs_log10fR0/0000/z_values_list.txt'))     # list of available redshifts

# %% [markdown]
# Split the data into training, validation and test data sets

# %%
emulation_data.calculate_data_split(n_train=n_train,                            # Number of training vectors per redshift
                                    n_test=n_test,                              # Number of test vectors per redsift
                                    n_splits=n_splits,
                                    verbosity=3,
                                    manual_split=True,
                                    test_indices=None,
                                    train_redshift_indices=[0],      # Indices of the redshifts used for the train vect.
                                    test_redshift_indices=[0])       # Indices of the redshifts used for the test vect.
# Out:
# ('number of wanted training vectors', 100)
# ('number of wanted test vectors', 2)
# ('redshift used for training', array([0.]))
# ('redshfit used for testing', array([0.]))

# %% [markdown]
# ## 3) PCA and GP interpolation

# %% [markdown]
# Import the looti module dictlearn which is used for PCA transformation and the training of intepolators

# %%
from looti import dictlearn as dcl

# %% [markdown]
# Choose the number of PCA components and specify the number of varying parameters

# %%
npca = 7
nparam = 7

# %% [markdown]
# Now the data is transformed into PCA space and a Gaussian Process (GP) is trained on the PCA components.
# <br>
# <br>
# Required input:
# - emulation_data
#
#
# Optional input:
# - Operator: type of interpolation (default = 'PCA')
#     - LIN: interpolation according to a simple spline
#     - PCA: interpolation over PCA components
#     - DL: interpolation over dictionary components of sparse DL representation
#     - GP: directly train a Gaussian Process on the data without further pre-processing
# - interp_type: type of interpolator
#     - GP: Gaussian Process
#     - int1d:

# %%
ratios_predicted, emulation_data, intobj = dcl.Predict_ratio(emulation_data,Operator="PCA",
                                                             train_noise=1e-10,                     # Noise for the GP's kernel
                                                             gp_n_rsts=40,                          # max times to restart the optimiser
                                                             ncomp=npca,                            # Number of components
                                                             gp_const=1,                            # Constant for the RBF kernel
                                                             gp_length=np.ones(nparam) ,            # Length for GP 
                                                             interp_type='GP',                      # Kind of interpolator
                                                             n_splits=n_splits,                     # Number of splits
                                                             test_indices=test_indices,             # Indices of test vectors
                                                             interp_dim=1,
                                                             return_interpolator=True,
                                                             pca_norm=True,
                                                             train_redshift_indices=[0],
                                                             test_redshift_indices=[0]
                                                             # min_k =1e-2,ma_k=10e1
                                                             )
# Out:
# ('Shape of PCA matrix: (102, 7)',)
# ('Number of PCA components: 7',)

# %% [markdown]
# ## 4) Save the trained interpolator

# %%
import pickle
save_path = '../interpolators/class_Asw0wa_DP/'
save_name = 'sigma8_z.sav'
# pickle.dump(intobj, open(save_path+save_name, 'wb'))

# %% [markdown]
# # Now repeat the same procedure for the other observables

# %% [markdown]
# ## Example 2: Non-linear power spectrum $P_{nonlin}$

# %%
FrameConstructor = rf.FrameConstructor(path_config_file='../readfile_configs/input4cast_lhs_Pnonlin.yaml')

# %%
dataframe_Pnonlin_ext = FrameConstructor.create_dataframe()
# dataframe_Pnonlin_ext.to_csv("../data/rwth_output/class_Asw0wa_DP/Pnonlin.csv")

# %%
dataframe_Pnonlin_ref = FrameConstructor.create_reference_dataframe()
# dataframe_ref.to_csv("../data/rwth_output/class_Asw0wa_DP/Pnonlin_ref.csv")

# %%
data_folder = '../data/rwth_output/class_Asw0wa_DP/' 
datafile_ext = 'Pnonlin'
datafile_ref = 'Pnonlin_ref'

# %%
emulation_data = dhl.DataHandle(datafile_ext,                   # file name of csv file containing input data
                                data_folder,                    # path to folder containing both external and reference dataframes
                                datafile_ref,                   # file name of csv file containing reference data
                                num_parameters=7,               # number of parameters to be interpolated
                                data_type='Pnonlin',            # type of observable to be emulated
                                features_name='k_grid',         # name of the grid in the data frames
                                features_to_Log=True,           # 
                                ratio_mode=False) 
emulation_data.read_csv_pandas()

# %%
emulation_data.calculate_ratio_by_redshifts(emulation_data.z_vals, normalize=True)

# %%
n_train = 100                                                  # Number of training vectors without taking acount the extrema 
n_test = 2                                                     # Number of test vectors without taking acount the extrema
n_splits = 1                                                   # Number of splits
test_indices=[random.sample(range(1, 1000), n_test)]           # List of list -of test indices, one list per split

z_list = list(np.loadtxt('../../input4cast/output/mg_camb_lhs_log10fR0/0000/z_values_list.txt'))      # list of available redshifts

# %%
emulation_data.calculate_data_split(n_train=n_train,                            # Number of training vectors per redshift
                                    n_test=n_test,                              # Number of test vectors per redsift
                                    n_splits=n_splits,
                                    verbosity=3,
                                    manual_split=True,
                                    test_indices=None,
                                    train_redshift_indices=list(range(5)),      # Indices of the redshifts used for the train vect.
                                    test_redshift_indices=list(range(5)))       # Indices of the redshifts used for the test vect.
# Out:
# ('number of wanted training vectors', 100)
# ('number of wanted test vectors', 2)
# ('redshift used for training', array([0.  , 0.05, 0.1 , 0.15, 0.2 ]))
# ('redshfit used for testing', array([0.  , 0.05, 0.1 , 0.15, 0.2 ]))

# %%
npca = 7
nparam = 8

# %%
ratios_predicted, emulation_data, intobj = dcl.Predict_ratio(emulation_data,Operator="PCA",
                                                             train_noise=1e-10,                     # Noise for the GP's kernel
                                                             gp_n_rsts=40,                          # max times to restart the optimiser
                                                             ncomp=npca,                            # Number of components
                                                             gp_const=1,                            # Constant for the RBF kernel
                                                             gp_length=np.ones(nparam) ,            # Length for GP 
                                                             interp_type='GP',                      # Kind of interpolator
                                                             n_splits=n_splits,                     # Number of splits
                                                             test_indices=test_indices,             # Indices of test vectors
                                                             interp_dim=1,
                                                             return_interpolator=True,
                                                             pca_norm=True,
                                                             train_redshift_indices=list(range(5)),
                                                             test_redshift_indices=list(range(5))
                                                             # min_k =1e-2,ma_k=10e1
                                                             )
# Out:
# ('Shape of PCA matrix: (510, 7)',)
# ('Number of PCA components: 7',)

# %%
import pickle
save_path = '../interpolators/class_Asw0wa_DP/'
save_name = 'D_Growth.sav'
pickle.dump(intobj, open(save_path+save_name, 'wb'))

# %% [markdown]
# ## Example 3: Growth factor $D$

# %%
from looti import datahandle as dhl
from looti import dictlearn as dcl
import numpy as np
import random

# %%
FrameConstructor = rf.FrameConstructor(path_config_file='../readfile_configs/input4cast_lhs_D_Growth.yaml')

# %%
dataframe_D_Growth_ext = FrameConstructor.create_dataframe()
# dataframe_D_Growth_ext.to_csv("../data/rwth_output/class_Asw0wa_DP/D_Growth.csv")

# %%
dataframe_D_Growth_ref = FrameConstructor.create_reference_dataframe()
# dataframe_D_Growth_ref.to_csv("../data/rwth_output/class_Asw0wa_DP/D_Growth_ref.csv")

# %%
data_folder = '../data/rwth_output/class_Asw0wa_DP/'
datafile_ext = 'D_Growth'
datafile_ref = 'D_Growth_ref'

# %%
emulation_data = dhl.DataHandle(datafile_ext,                   # file name of csv file containing input data
                                data_folder,                    # path to folder containing both external and reference dataframes
                                datafile_ref,                   # file name of csv file containing reference data
                                num_parameters=7,               # number of parameters to be interpolated
                                data_type='D_Growth',           # type of observable to be emulated
                                features_name='k_grid',         # name of the grid in the data frames
                                features_to_Log=True,           # 
                                ratio_mode=False) 
emulation_data.read_csv_pandas()

# %%
emulation_data.calculate_ratio_by_redshifts(emulation_data.z_vals, normalize=True)

# %%
n_train = 100                                                  # Number of training vectors without taking acount the extrema 
n_test = 2                                                     # Number of test vectors without taking acount the extrema
n_splits = 1                                                   # Number of splits
test_indices=[random.sample(range(1, 1000), n_test)]           # List of list -of test indices, one list per split

z_list = list(np.loadtxt('../../input4cast/output/mg_camb_lhs_log10fR0/0000/z_values_list.txt'))      # list of available redshifts

# %%
emulation_data.calculate_data_split(n_train=n_train,                            # Number of training vectors per redshift
                                    n_test=n_test,                              # Number of test vectors per redsift
                                    n_splits=n_splits,
                                    verbosity=3,
                                    manual_split=True,
                                    test_indices=None,
                                    train_redshift_indices=list(range(5)),      # Indices of the redshifts used for the train vect.
                                    test_redshift_indices=list(range(5)))       # Indices of the redshifts used for the test vect.
# Out:
# ('number of wanted training vectors', 100)
# ('number of wanted test vectors', 2)
# ('redshift used for training', array([0.  , 0.05, 0.1 , 0.15, 0.2 ]))
# ('redshfit used for testing', array([0.  , 0.05, 0.1 , 0.15, 0.2 ]))

# %%
npca = 7
nparam = 8

# %%
ratios_predicted, emulation_data, intobj = dcl.Predict_ratio(emulation_data,Operator="PCA",
                                                             train_noise=1e-10,                     # Noise for the GP's kernel
                                                             gp_n_rsts=40,                          # max times to restart the optimiser
                                                             ncomp=npca,                            # Number of components
                                                             gp_const=1,                            # Constant for the RBF kernel
                                                             gp_length=np.ones(nparam) ,            # Length for GP 
                                                             interp_type='GP',                      # Kind of interpolator
                                                             n_splits=n_splits,                     # Number of splits
                                                             test_indices=test_indices,             # Indices of test vectors
                                                             interp_dim=1,
                                                             return_interpolator=True,
                                                             pca_norm=True,
                                                             train_redshift_indices=list(range(5)),
                                                             test_redshift_indices=list(range(5))
                                                             # min_k =1e-2,ma_k=10e1
                                                             )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 ratios_predicted, emulation_data, intobj = dcl.Predict_ratio(emulation_data,Operator="PCA",
#       2                                                              train_noise=1e-10,                     # Noise for the GP's kernel
#       3                                                              gp_n_rsts=40,                          # max times to restart the optimiser
#       4                                                              ncomp=npca,                            # Number of components
#       5                                                              gp_const=1,                            # Constant for the RBF kernel
#       6                                                              gp_length=np.ones(nparam) ,            # Length for GP
#       7                                                              interp_type='GP',                      # Kind of interpolator
#       8                                                              n_splits=n_splits,                     # Number of splits
#       9                                                              test_indices=test_indices,             # Indices of test vectors
#      10                                                              interp_dim=1,
#      11                                                              return_interpolator=True,
#      12                                                              pca_norm=True,
#      13                                                              train_redshift_indices=list(range(5)),
#      14                                                              test_redshift_indices=list(range(5))
#      15                                                              # min_k =1e-2,ma_k=10e1
#      16                                                              )
#
# File ~/looti/looti/dictlearn.py:505, in Predict_ratio(emulation_data, Operator, ncomp, train_noise, gp_n_rsts, gp_const, gp_length, gp_bounds, interp_type, interp_dim, n_train, n_test, n_splits, split, test_indices, train_redshift_indices, test_redshift_indices, return_interpolator, thinning, min_k, max_k, mask, pca_norm)
#     503     intobj = LearnData(PCAop)
#     504 ###Perfoming the PCA reduction and interpolation
# --> 505     intobj.interpolate(train_data=emulation_data.matrix_datalearn_dict['train'],
#     506                        train_samples=emulation_data.train_samples,train_noise = train_noise, pca_norm=pca_norm)
#     507     ratios_predicted = intobj.predict(emulation_data.test_samples, pca_norm)
#     509     if return_interpolator == True:
#
# File ~/looti/looti/dictlearn.py:123, in LearnData.interpolate(self, train_data, train_samples, train_noise, pca_norm)
#     121     self.LINtraining()
#     122 elif self.method == "PCA":
# --> 123     self.PCAtraining(pca_norm)
#     124 elif self.method == "DL":
#     125     self.DLtraining()
#
# File ~/looti/looti/dictlearn.py:149, in LearnData.PCAtraining(self, pca_norm)
#     146 self.pca=pca## take n principal components
#     148 if pca_norm == True:
# --> 149     matPCA_raw=pca.fit(self.trainspace_mat).transform(self.trainspace_mat)
#     150     self.matPCA_mean = matPCA_raw.mean(axis=0)
#     151     self.matPCA_std = matPCA_raw.std(axis=0)
#
# File ~/miniconda3/envs/lootiemu/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:435, in PCA.fit(self, X, y)
#     417 """Fit the model with X.
#     418
#     419 Parameters
#    (...)
#     431     Returns the instance itself.
#     432 """
#     433 self._validate_params()
# --> 435 self._fit(X)
#     436 return self
#
# File ~/miniconda3/envs/lootiemu/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:485, in PCA._fit(self, X)
#     479 if issparse(X):
#     480     raise TypeError(
#     481         "PCA does not support sparse input. See "
#     482         "TruncatedSVD for a possible alternative."
#     483     )
# --> 485 X = self._validate_data(
#     486     X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     487 )
#     489 # Handle n_components==None
#     490 if self.n_components is None:
#
# File ~/miniconda3/envs/lootiemu/lib/python3.11/site-packages/sklearn/base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File ~/miniconda3/envs/lootiemu/lib/python3.11/site-packages/sklearn/utils/validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File ~/miniconda3/envs/lootiemu/lib/python3.11/site-packages/sklearn/utils/validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# PCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
import pickle
save_path = '../interpolators/class_Asw0wa_DP/'
save_name = 'Pnonlin.sav'
pickle.dump(intobj, open(save_path+save_name, 'wb'))
